# %%
from langchain_core.prompts import PromptTemplate

template = """\
# Instrucciones para el Asistente de IA

Recuerda que hoy es {fecha_actual}

## Rol
Eres un experto en marketing digital con 10 años de experiencia.

## Tarea
Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción.

## Texto del Anuncio
{texto_anuncio}

## Formato de Salida
- *Sugerencia 1:* [Tu primera sugerencia]
- *Sugerencia 2:* [Tu segunda sugerencia]
- *Sugerencia 3:* [Tu tercera sugerencia]
"""

prompt_template = PromptTemplate.from_template(template, partial_variables={"fecha_actual": "2026-07-24"})
prompt = prompt_template.format(texto_anuncio="Compra ahora y obtén un 50% de descuento en todos nuestros productos.")
print(prompt)
# Out:
# # Instrucciones para el Asistente de IA
#
# Recuerda que hoy es 2026-07-24
#
# ## Rol
# Eres un experto en marketing digital con 10 años de experiencia.
#
# ## Tarea
# Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocándote en el llamado a la acción.
#
# ## Texto del Anuncio
# Compra ahora y obtén un 50% de descuento en todos nuestros productos.
#
# ## Formato de Salida
# - *Sugerencia 1:* [Tu primera sugerencia]
# - *Sugerencia 2:* [Tu segunda sugerencia]
# - *Sugerencia 3:* [Tu tercera sugerencia]

# %%
template = """\
Your are a helpful that responds to the user's message

{% if name %}
The user's name is {{ name }} and you can call them by that name
{% endif -%}

The user's message is: {{ user_message }}
"""
prompt_template = PromptTemplate.from_template(template, template_format="jinja2")
prompt = prompt_template.format(user_message="como puedo mejorar mi sitio web?", name="Juan")
print(prompt)
# Out:
# Your are a helpful that responds to the user's message
#
# The user's name is Juan and you can call them by that name
# The user's message is: como puedo mejorar mi sitio web?
